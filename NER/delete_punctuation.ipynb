# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/nckh/daucau.txt
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/nckh/daucau.txt'
# /content/drive/MyDrive/nckh

# %%
from google.colab import files
files.upload(daucau.txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c62b990a6f8b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload(daucau.txt)
#
# NameError: name 'daucau' is not defined

# %%
with open('daucau.txt','r')as myFile:

    str1=myFile.read()

    punctuation = ['(', ')', '?', ':', ';', ',', '.', '!', '/', '"', "'",'-'] 

for i in punctuation:

        str1 = str1.replace(i," ") 
        myList=[]
        myList.extend(str1.split(" "))
print (str1) 
for i in myList:

    print(i,end='\n')
# Out:
# fehfiu  fe rta grg fsrg  trt  ewtwe
# fehfiu
#
# fe
# rta
# grg
# fsrg
#
# trt
#
# ewtwe
